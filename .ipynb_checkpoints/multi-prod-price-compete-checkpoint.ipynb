# %%
import pandas as pd
import numpy as np
import inventorize3 as inv

# %%
df=pd.read_csv('multvariate_slides.csv')
df.head()
# Out:
#    week  Price_product3  Price_product1  Price_product2  Price_product4  \
# 0     1       92.926829       60.000000           100.0      130.000000
# 1     2      117.118644       65.000000           110.0      140.000000
# 2     3      103.302752       60.000000           100.0      130.000000
# 3     4      115.769231       65.000000           110.0      140.000000
# 4     5      106.769231       60.054496           100.0      129.727273
#
#    sales_product3  sales_product1  sales_product2  sales_product4
# 0              86             700             406             124
# 1             257            1652             979             295
# 2             230            1999            1197             358
# 3             203             848             496             170
# 4             144            1278             826             206

# %%
df.iloc[:,1:5].describe()
# Out:
#        Price_product3  Price_product1  Price_product2  Price_product4
# count      101.000000      101.000000      101.000000      101.000000
# mean       110.590879       62.371903      104.746805      134.692887
# std          5.877259        2.504866        5.018190        5.103280
# min         92.926829       59.968750       99.924528      124.666667
# 25%        105.506329       60.000000      100.000000      130.000000
# 50%        108.275862       60.000000      100.000000      130.000000
# 75%        115.722543       65.000000      110.000000      140.000000
# max        124.318182       65.000000      110.000000      140.000000

# %%
x=df.iloc[:,1:5]
x=sm.add_constant(x)

# %%
import statsmodels.api as sm

# %%
model_product=sm.OLS(df['sales_product1'],x).fit()

# %%
model_product.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:         sales_product1   R-squared:                       0.064
# Model:                            OLS   Adj. R-squared:                  0.025
# Method:                 Least Squares   F-statistic:                     1.631
# Date:                Thu, 23 Jan 2025   Prob (F-statistic):              0.173
# Time:                        10:44:20   Log-Likelihood:                -749.74
# No. Observations:                 101   AIC:                             1509.
# Df Residuals:                      96   BIC:                             1523.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
model_product=sm.OLS(df['sales_product2'],x).fit()
model_product.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:         sales_product2   R-squared:                       0.121
# Model:                            OLS   Adj. R-squared:                  0.084
# Method:                 Least Squares   F-statistic:                     3.304
# Date:                Thu, 23 Jan 2025   Prob (F-statistic):             0.0139
# Time:                        10:44:40   Log-Likelihood:                -727.98
# No. Observations:                 101   AIC:                             1466.
# Df Residuals:                      96   BIC:                             1479.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
model_product=sm.OLS(df['sales_product3'],x).fit()
model_product.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:         sales_product3   R-squared:                       0.080
# Model:                            OLS   Adj. R-squared:                  0.042
# Method:                 Least Squares   F-statistic:                     2.098
# Date:                Thu, 23 Jan 2025   Prob (F-statistic):             0.0870
# Time:                        10:44:51   Log-Likelihood:                -647.37
# No. Observations:                 101   AIC:                             1305.
# Df Residuals:                      96   BIC:                             1318.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
model_product=sm.OLS(df['sales_product4'],x).fit()
model_product.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:         sales_product4   R-squared:                       0.132
# Model:                            OLS   Adj. R-squared:                  0.096
# Method:                 Least Squares   F-statistic:                     3.662
# Date:                Thu, 23 Jan 2025   Prob (F-statistic):            0.00806
# Time:                        10:44:57   Log-Likelihood:                -589.86
# No. Observations:                 101   AIC:                             1190.
# Df Residuals:                      96   BIC:                             1203.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
# multinomial logit models

# %%
df=pd.read_csv('multi_slides.csv')
df.head()
# Out:
#    product1  product2    product3  product4  choice
# 0      60.0     100.0  109.230769     130.0       2
# 1      60.0     100.0  106.444444     130.0       2
# 2      60.0     100.0  104.285714     130.0       4
# 3      65.0     110.0  118.360656     140.0       3
# 4      60.0     100.0  110.000000     130.0       1

# %%
inv.Multi_Competing_optimization(df.iloc[:4000,0:4],df.loc[:4000,'choice'],4,[40,60,70,100])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\optimize\_minimize.py:1010, in _validate_bounds(bounds, x0, meth)
#    1009 try:
# -> 1010     bounds.lb = np.broadcast_to(bounds.lb, x0.shape)
#    1011     bounds.ub = np.broadcast_to(bounds.ub, x0.shape)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\lib\_stride_tricks_impl.py:422, in broadcast_to(array, shape, subok)
#     378 """Broadcast an array to a new shape.
#     379
#     380 Parameters
#    (...)
#     420        [1, 2, 3]])
#     421 """
# --> 422 return _broadcast_to(array, shape, subok=subok, readonly=True)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\lib\_stride_tricks_impl.py:358, in _broadcast_to(array, shape, subok, readonly)
#     357 extras = []
# --> 358 it = np.nditer(
# ...
